# %%
#Librerias

import pandas as pd
import numpy as np
import yaml
import sys
import os

# %%
# Función para el agregado de variables

def agregar_variables(dataset):
    print("Inicio agregar_variables()")

    dataset['nvar_1'] = dataset['Quantity'] / dataset['Age']
    dataset['nvar_2'] = dataset['Fee'] / dataset['Age']
    dataset['nvar_3'] = dataset['VideoAmt'] / dataset['Age']
    dataset['nvar_4'] = dataset['PhotoAmt'] / dataset['Age']
    dataset['nvar_5'] = dataset['AdoptionSpeed'] / dataset['Age']

    dataset['nvar_6'] = dataset['AdoptionSpeed'] / dataset['Quantity']
    dataset['nvar_7'] = dataset['AdoptionSpeed'] / dataset['Fee']
    dataset['nvar_8'] = dataset['AdoptionSpeed'] / dataset['VideoAmt']
    dataset['nvar_9'] = dataset['AdoptionSpeed'] / dataset['PhotoAmt']    

    dataset['nvar_10'] = dataset['Quantity'] / dataset['AdoptionSpeed']
    dataset['nvar_11'] = dataset['Quantity'] / dataset['Fee']
    dataset['nvar_12'] = dataset['Quantity'] / dataset['VideoAmt']
    dataset['nvar_13'] = dataset['Quantity'] / dataset['PhotoAmt'] 
    
    dataset['nvar_14'] = dataset['Fee'] / dataset['AdoptionSpeed']
    dataset['nvar_15'] = dataset['Fee'] / dataset['Quantity']
    dataset['nvar_16'] = dataset['Fee'] / dataset['VideoAmt']
    dataset['nvar_17'] = dataset['Fee'] / dataset['PhotoAmt'] 

    dataset['nvar_18'] = dataset['VideoAmt'] / dataset['AdoptionSpeed']
    dataset['nvar_19'] = dataset['VideoAmt'] / dataset['Quantity']
    dataset['nvar_20'] = dataset['VideoAmt'] / dataset['PhotoAmt']
    dataset['nvar_21'] = dataset['VideoAmt'] / dataset['VideoAmt'] 

    dataset['nvar_22'] = dataset['Age'] / dataset['AdoptionSpeed']
    dataset['nvar_23'] = dataset['Age'] / dataset['Quantity']
    dataset['nvar_24'] = dataset['Age'] / dataset['PhotoAmt']
    dataset['nvar_25'] = dataset['Age'] / dataset['VideoAmt'] 

    dataset['nvar_26'] = dataset['PhotoAmt'] / dataset['AdoptionSpeed']
    dataset['nvar_27'] = dataset['PhotoAmt'] / dataset['Quantity']
    dataset['nvar_28'] = dataset['PhotoAmt'] / dataset['Fee']
    dataset['nvar_29'] = dataset['PhotoAmt'] / dataset['VideoAmt']
    
    dataset['nvar_30'] = dataset['Quantity'] / (dataset['Age'] ** 2)
    dataset['nvar_31'] = dataset['Fee'] / (dataset['Age'] ** 2)
    dataset['nvar_32'] = dataset['VideoAmt'] / (dataset['Age'] ** 2)
    dataset['nvar_33'] = dataset['PhotoAmt'] / (dataset['Age'] ** 2)
    dataset['nvar_34'] = dataset['AdoptionSpeed'] / (dataset['Age'] ** 2)

    dataset['nvar_35'] = (dataset['Quantity'] ** 2) / dataset['Age']
    dataset['nvar_36'] = (dataset['Fee'] ** 2) / dataset['Age']
    dataset['nvar_37'] = (dataset['VideoAmt'] ** 2) / dataset['Age']
    dataset['nvar_38'] = (dataset['PhotoAmt'] ** 2) / dataset['Age']
    dataset['nvar_39'] = (dataset['AdoptionSpeed'] ** 2) / dataset['Age']

    dataset['nvar_40'] = (dataset['AdoptionSpeed'] ** 2) / dataset['Quantity']
    dataset['nvar_41'] = (dataset['AdoptionSpeed'] ** 2) / dataset['Fee']
    dataset['nvar_42'] = (dataset['AdoptionSpeed'] ** 2) / dataset['VideoAmt']
    dataset['nvar_43'] = (dataset['AdoptionSpeed'] ** 2)/ dataset['PhotoAmt'] 

    dataset['nvar_44'] = dataset['AdoptionSpeed'] / (dataset['Quantity'] ** 2)
    dataset['nvar_45'] = dataset['AdoptionSpeed'] / (dataset['Fee'] ** 2)
    dataset['nvar_46'] = dataset['AdoptionSpeed'] / (dataset['VideoAmt'] ** 2)
    dataset['nvar_47'] = dataset['AdoptionSpeed']/ (dataset['PhotoAmt'] ** 2) 

    dataset['nvar_48'] = dataset['Quantity'] / (dataset['AdoptionSpeed'] ** 2)
    dataset['nvar_49'] = dataset['Quantity'] / (dataset['Fee'] ** 2)
    dataset['nvar_50'] = dataset['Quantity'] / (dataset['VideoAmt'] ** 2)
    dataset['nvar_51'] = dataset['Quantity'] / (dataset['PhotoAmt'] ** 2) 

    dataset['nvar_53'] = (dataset['Quantity'] ** 2) / dataset['AdoptionSpeed']
    dataset['nvar_54'] = (dataset['Quantity'] ** 2) / dataset['Fee']
    dataset['nvar_55'] = (dataset['Quantity'] ** 2) / dataset['VideoAmt']
    dataset['nvar_56'] = (dataset['Quantity'] ** 2) / dataset['PhotoAmt'] 

    dataset['nvar_57'] = (dataset['Fee'] ** 2)/ dataset['AdoptionSpeed']
    dataset['nvar_58'] = (dataset['Fee'] ** 2) / dataset['Quantity']
    dataset['nvar_59'] = (dataset['Fee'] ** 2) / dataset['VideoAmt']
    dataset['nvar_60'] = (dataset['Fee'] ** 2) / dataset['PhotoAmt'] 

    dataset['nvar_61'] = dataset['Fee'] / (dataset['AdoptionSpeed'] ** 2)
    dataset['nvar_62'] = dataset['Fee'] / (dataset['Quantity'] ** 2)
    dataset['nvar_63'] = dataset['Fee'] / (dataset['VideoAmt'] ** 2)
    dataset['nvar_64'] = dataset['Fee'] / (dataset['PhotoAmt'] ** 2) 

    dataset['nvar_65'] = dataset['VideoAmt'] / (dataset['AdoptionSpeed'] ** 2)
    dataset['nvar_66'] = dataset['VideoAmt'] / (dataset['Quantity'] ** 2)
    dataset['nvar_67'] = dataset['VideoAmt'] / (dataset['Fee'] ** 2)
    dataset['nvar_68'] = dataset['VideoAmt'] / (dataset['PhotoAmt'] ** 2)

    dataset['nvar_69'] = (dataset['VideoAmt'] ** 2) / dataset['AdoptionSpeed']
    dataset['nvar_70'] = (dataset['VideoAmt'] ** 2) / dataset['Quantity']
    dataset['nvar_71'] = (dataset['VideoAmt'] ** 2) / dataset['PhotoAmt']
    dataset['nvar_72'] = (dataset['VideoAmt'] ** 2) / dataset['PhotoAmt'] 

    dataset['nvar_73'] = dataset['Age'] / (dataset['AdoptionSpeed'] ** 2)
    dataset['nvar_74'] = dataset['Age'] / (dataset['Quantity'] ** 2)
    dataset['nvar_75'] = dataset['Age'] / (dataset['PhotoAmt'] ** 2)
    dataset['nvar_76'] = dataset['Age'] / (dataset['VideoAmt'] ** 2)

    dataset['nvar_77'] = (dataset['Age'] ** 2) / dataset['AdoptionSpeed']
    dataset['nvar_78'] = (dataset['Age'] ** 2) / dataset['Quantity']
    dataset['nvar_79'] = (dataset['Age'] ** 2)/ dataset['PhotoAmt']
    dataset['nvar_80'] = (dataset['Age'] ** 2) / dataset['VideoAmt'] 

    dataset['nvar_81'] = (dataset['PhotoAmt'] ** 2)/ dataset['AdoptionSpeed']
    dataset['nvar_82'] = (dataset['PhotoAmt'] ** 2) / dataset['Quantity']
    dataset['nvar_83'] = (dataset['PhotoAmt'] ** 2) / dataset['Fee']
    dataset['nvar_84'] = (dataset['PhotoAmt'] ** 2)/ dataset['VideoAmt']

    dataset['nvar_85'] = dataset['PhotoAmt'] / (dataset['AdoptionSpeed'] ** 2)
    dataset['nvar_86'] = dataset['PhotoAmt'] / (dataset['Quantity'] ** 2)
    dataset['nvar_87'] = dataset['PhotoAmt'] / (dataset['Fee'] ** 2)
    dataset['nvar_88'] = dataset['PhotoAmt'] / (dataset['VideoAmt'] ** 2)

    # prueba con las variables cualitativas

    dataset['nvar_89'] = dataset['MaturitySize'] / dataset['Age']
    dataset['nvar_90'] = dataset['FurLength'] / dataset['Age']
    dataset['nvar_91'] = dataset['Vaccinated'] / dataset['Age']
    dataset['nvar_92'] = dataset['Dewormed'] / dataset['Age']
    dataset['nvar_93'] = dataset['Sterilized'] / dataset['Age']
    dataset['nvar_94'] = dataset['Health'] / dataset['Age']

    dataset['nvar_95'] = dataset['MaturitySize'] / dataset['AdoptionSpeed']
    dataset['nvar_96'] = dataset['FurLength'] / dataset['AdoptionSpeed']
    dataset['nvar_97'] = dataset['Vaccinated'] / dataset['AdoptionSpeed']
    dataset['nvar_98'] = dataset['Dewormed'] / dataset['AdoptionSpeed']
    dataset['nvar_99'] = dataset['Sterilized'] / dataset['AdoptionSpeed']
    dataset['nvar_100'] = dataset['Health'] / dataset['AdoptionSpeed']

    dataset['nvar_101'] = dataset['MaturitySize'] / (dataset['Age'] ** 2)
    dataset['nvar_102'] = dataset['FurLength'] / (dataset['Age'] ** 2)
    dataset['nvar_103'] = dataset['Vaccinated'] / (dataset['Age'] ** 2)
    dataset['nvar_104'] = dataset['Dewormed'] / (dataset['Age'] ** 2)
    dataset['nvar_105'] = dataset['Sterilized'] / (dataset['Age'] ** 2)
    dataset['nvar_106'] = dataset['Health'] / (dataset['Age'] ** 2)

    dataset['nvar_107'] = dataset['MaturitySize'] / (dataset['AdoptionSpeed'] ** 2)
    dataset['nvar_108'] = dataset['FurLength'] / (dataset['AdoptionSpeed'] ** 2)
    dataset['nvar_109'] = dataset['Vaccinated'] / (dataset['AdoptionSpeed'] ** 2)
    dataset['nvar_110'] = dataset['Dewormed'] / (dataset['AdoptionSpeed'] ** 2)
    dataset['nvar_111'] = dataset['Sterilized'] / (dataset['AdoptionSpeed'] ** 2)
    dataset['nvar_112'] = dataset['Health'] / (dataset['AdoptionSpeed'] ** 2)

    dataset['nvar_113'] = (dataset['MaturitySize'] ** 2) / dataset['Age']
    dataset['nvar_114'] = (dataset['FurLength'] ** 2) / dataset['Age']
    dataset['nvar_115'] = (dataset['Vaccinated'] ** 2) / dataset['Age']
    dataset['nvar_116'] = (dataset['Dewormed'] ** 2) / dataset['Age']
    dataset['nvar_117'] = (dataset['Sterilized'] ** 2) / dataset['Age']
    dataset['nvar_118'] = (dataset['Health'] ** 2) / dataset['Age']

    dataset['nvar_119'] = (dataset['MaturitySize'] ** 2) / dataset['AdoptionSpeed']
    dataset['nvar_120'] = (dataset['FurLength'] ** 2) / dataset['AdoptionSpeed']
    dataset['nvar_121'] = (dataset['Vaccinated'] ** 2) / dataset['AdoptionSpeed']
    dataset['nvar_122'] = (dataset['Dewormed'] ** 2) / dataset['AdoptionSpeed']
    dataset['nvar_123'] = (dataset['Sterilized'] ** 2) / dataset['AdoptionSpeed']
    dataset['nvar_124'] = (dataset['Health'] ** 2) / dataset['AdoptionSpeed']

    # Manejo de valores infinitos y NaN
    infinitos = dataset.isin([np.inf, -np.inf]).sum().sum()
    if infinitos > 0:
        print(f"ATENCIÓN: hay {infinitos} valores infinitos en tu dataset. Serán convertidos a NA")
        dataset.replace([np.inf, -np.inf], np.nan, inplace=True)

    nans = dataset.isna().sum().sum()
    if nans > 0:
        print(f"ATENCIÓN: hay {nans} valores NaN en tu dataset. Serán convertidos a 0")
        dataset.fillna(0, inplace=True)

    print("Fin agregar_variables()")

#def main():
    # Argumentos de entrada: archivo CSV de entrada y ruta de salida
#    if len(sys.argv) < 3:
#        print("Uso: fe.py <"C:\Users\natal\Documents\GitHub\pet_project\pet_project\pet-competition\data\01_raw\train\train.csv"> <C:\Users\natal\Documents\GitHub\pet_project\pet_project\pet-competition\data\01_raw\train>")
#        sys.exit(1)
    
#    input_file = sys.argv[1]    # Ruta del archivo CSV de entrada
   
def main():
    # Argumentos de entrada: archivo CSV de entrada, ruta de salida y nombre del archivo de salida
    #if len(sys.argv) < 3:
    #    print("Uso: fe.py")
    #    sys.exit(1)
    
    input_file = '/Users/natal/Documents/GitHub/pet_project/pet_project/pet-competition/data/01_raw/train/train.csv'  # Ruta del archivo CSV de entrada
    output_directory = '/Users/natal/Documents/GitHub/pet_project/pet_project/pet-competition/data/01_raw/train'  # Ruta del directorio de salida
    
    # Definir el nombre del archivo de salida
    output_file = os.path.join(output_directory, 'train_FE.csv')
    
    # Cargar dataset
    dataset = pd.read_csv(input_file)
    
    # Llamar a la función para agregar variables
    agregar_variables(dataset)
    
    # Guardar el nuevo dataset
    dataset.to_csv(output_file, index=False)
    print(f"Dataset guardado exitosamente en {output_file}")

if __name__ == "__main__":
    main()
# Out:
# Inicio agregar_variables()
# ATENCIÓN: hay 308626 valores infinitos en tu dataset. Serán convertidos a NA
# C:\Users\natal\AppData\Local\Temp\ipykernel_19076\1628310935.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataset['nvar_99'] = dataset['Sterilized'] / dataset['AdoptionSpeed']
# C:\Users\natal\AppData\Local\Temp\ipykernel_19076\1628310935.py:128: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataset['nvar_100'] = dataset['Health'] / dataset['AdoptionSpeed']
# ...
